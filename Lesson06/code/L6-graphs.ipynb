# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stats = [45, 52, 60, 68, 75]

plt.figure(figsize=(8, 1))
sns.boxplot(x=stats)
plt.title('Boxplot for 5-number Summary in Practice Question 2')
plt.yticks([])
plt.xlabel('Values')

plt.savefig('../images/Fig652_Solution.png')
